# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/layoffs.csv')
df
# Out:
#                company       location     industry  total_laid_off  \
# 0            Atlassian         Sydney        Other           500.0
# 1             SiriusXM  New York City        Media           475.0
# 2               Alerzo         Ibadan       Retail           400.0
# 3               UpGrad         Mumbai    Education           120.0
# 4                 Loft      Sao Paulo  Real Estate           340.0
# ...                ...            ...          ...             ...
# 2356         Blackbaud     Charleston        Other           500.0
# 2357             Yahoo    SF Bay Area     Consumer          1600.0
# 2358             Hibob       Tel Aviv           HR            70.0
# 2359            Casper  New York City       Retail             NaN
# 2360  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 0                    0.05    3/6/2023  Post-IPO      Australia
# ...

# %%
df.head()
# Out:
#      company       location     industry  total_laid_off  percentage_laid_off  \
# 0  Atlassian         Sydney        Other           500.0                 0.05
# 1   SiriusXM  New York City        Media           475.0                 0.08
# 2     Alerzo         Ibadan       Retail           400.0                  NaN
# 3     UpGrad         Mumbai    Education           120.0                  NaN
# 4       Loft      Sao Paulo  Real Estate           340.0                 0.15
#
#        date     stage        country  funds_raised_millions
# 0  3/6/2023  Post-IPO      Australia                  210.0
# 1  3/6/2023  Post-IPO  United States                  525.0
# 2  3/6/2023  Series B        Nigeria                   16.0
# 3  3/6/2023   Unknown          India                  631.0
# 4  3/3/2023   Unknown         Brazil                  788.0

# %%
 pd.set_option('display.max.rows',7)
# pd.set_option('display.max.columns',10)
# df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2361 entries, 0 to 2360
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   company                2361 non-null   object
#  1   location               2361 non-null   object
#  2   industry               2357 non-null   object
#  3   total_laid_off         1621 non-null   float64
#  4   percentage_laid_off    1576 non-null   float64
#  5   date                   2360 non-null   object
#  6   stage                  2355 non-null   object
#  7   country                2361 non-null   object
#  8   funds_raised_millions  2152 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 166.1+ KB

# %%
df.shape
# Out:
# (2361, 9)

# %%
df.tail(2)
# Out:
#                company       location  industry  total_laid_off  \
# 2359            Casper  New York City    Retail             NaN
# 2360  Wildlife Studios      Sao Paulo  Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 2359                  NaN   9/14/2021  Post-IPO  United States
# 2360                  0.2  11/28/2022   Unknown         Brazil
#
#       funds_raised_millions
# 2359                  339.0
# 2360                  260.0

# %%
df.head()
# Out:
#      company       location     industry  total_laid_off  percentage_laid_off  \
# 0  Atlassian         Sydney        Other           500.0                 0.05
# 1   SiriusXM  New York City        Media           475.0                 0.08
# 2     Alerzo         Ibadan       Retail           400.0                  NaN
# 3     UpGrad         Mumbai    Education           120.0                  NaN
# 4       Loft      Sao Paulo  Real Estate           340.0                 0.15
#
#        date     stage        country  funds_raised_millions
# 0  3/6/2023  Post-IPO      Australia                  210.0
# 1  3/6/2023  Post-IPO  United States                  525.0
# 2  3/6/2023  Series B        Nigeria                   16.0
# 3  3/6/2023   Unknown          India                  631.0
# 4  3/3/2023   Unknown         Brazil                  788.0

# %%
df[df['total_laid_off']>10000]
# Out:
#     company     location  industry  total_laid_off  percentage_laid_off  \
# 281  Google  SF Bay Area  Consumer         12000.0                 0.06
# 749    Meta  SF Bay Area  Consumer         11000.0                 0.13
#
#           date     stage        country  funds_raised_millions
# 281  1/20/2023  Post-IPO  United States                   26.0
# 749  11/9/2022  Post-IPO  United States                26000.0

# %%
specific_country=['Brazil','Nepal']
df[df['country'].isin(specific_country)]
# Out:
#                company   location     industry  total_laid_off  \
# 4                 Loft  Sao Paulo  Real Estate           340.0
# 13          Ambev Tech   Blumenau         Food            50.0
# 20               iFood  Sao Paulo         Food           355.0
# ...                ...        ...          ...             ...
# 2284              Loft  Sao Paulo  Real Estate            47.0
# 2290            Bcredi   Curitiba      Finance             NaN
# 2360  Wildlife Studios  Sao Paulo     Consumer           300.0
#
#       percentage_laid_off        date       stage country  \
# 4                    0.15    3/3/2023     Unknown  Brazil
# 13                    NaN    3/2/2023    Acquired  Brazil
# 20                   0.06    3/1/2023  Subsidiary  Brazil
# ...                   ...         ...         ...     ...
# 2284                  NaN   3/27/2020    Series C  Brazil
# 2290                  NaN   3/27/2020    Series A  Brazil
# ...

# %%
df['country']
# Out:
# 0           Australia
# 1       United States
# 2             Nigeria
#             ...
# 2358           Israel
# 2359    United States
# 2360           Brazil
# Name: country, Length: 2361, dtype: object

# %%
df[df['country'].str.contains('zil')]
# Out:
#                company   location     industry  total_laid_off  \
# 4                 Loft  Sao Paulo  Real Estate           340.0
# 13          Ambev Tech   Blumenau         Food            50.0
# 20               iFood  Sao Paulo         Food           355.0
# ...                ...        ...          ...             ...
# 2284              Loft  Sao Paulo  Real Estate            47.0
# 2290            Bcredi   Curitiba      Finance             NaN
# 2360  Wildlife Studios  Sao Paulo     Consumer           300.0
#
#       percentage_laid_off        date       stage country  \
# 4                    0.15    3/3/2023     Unknown  Brazil
# 13                    NaN    3/2/2023    Acquired  Brazil
# 20                   0.06    3/1/2023  Subsidiary  Brazil
# ...                   ...         ...         ...     ...
# 2284                  NaN   3/27/2020    Series C  Brazil
# 2290                  NaN   3/27/2020    Series A  Brazil
# ...

# %%
df.set_index('country')
# Out:
#                         company       location  industry  total_laid_off  \
# country
# Australia             Atlassian         Sydney     Other           500.0
# United States          SiriusXM  New York City     Media           475.0
# Nigeria                  Alerzo         Ibadan    Retail           400.0
# ...                         ...            ...       ...             ...
# Israel                    Hibob       Tel Aviv        HR            70.0
# United States            Casper  New York City    Retail             NaN
# Brazil         Wildlife Studios      Sao Paulo  Consumer           300.0
#
#                percentage_laid_off        date     stage  \
# country
# Australia                     0.05    3/6/2023  Post-IPO
# United States                 0.08    3/6/2023  Post-IPO
# Nigeria                        NaN    3/6/2023  Series B
# ...                            ...         ...       ...
# Israel                        0.30   3/30/2020  Series A
# ...

# %%
df.filter(items=['company','location'])
# Out:
#                company       location
# 0            Atlassian         Sydney
# 1             SiriusXM  New York City
# 2               Alerzo         Ibadan
# ...                ...            ...
# 2358             Hibob       Tel Aviv
# 2359            Casper  New York City
# 2360  Wildlife Studios      Sao Paulo
#
# [2361 rows x 2 columns]

# %%
# df.reset_index(drop=True)

# %%
df.loc[0]
# Out:
# company                  Atlassian
# location                    Sydney
# industry                     Other
#                            ...
# stage                     Post-IPO
# country                  Australia
# funds_raised_millions        210.0
# Name: 0, Length: 9, dtype: object

# %%
df.loc[1,'country']
# Out:
# 'United States'

# %%
df.iloc[3]
# Out:
# company                     UpGrad
# location                    Mumbai
# industry                 Education
#                            ...
# stage                      Unknown
# country                      India
# funds_raised_millions        631.0
# Name: 3, Length: 9, dtype: object

# %%
df
# Out:
#                company       location  industry  total_laid_off  \
# 0            Atlassian         Sydney     Other           500.0
# 1             SiriusXM  New York City     Media           475.0
# 2               Alerzo         Ibadan    Retail           400.0
# ...                ...            ...       ...             ...
# 2358             Hibob       Tel Aviv        HR            70.0
# 2359            Casper  New York City    Retail             NaN
# 2360  Wildlife Studios      Sao Paulo  Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 0                    0.05    3/6/2023  Post-IPO      Australia
# 1                    0.08    3/6/2023  Post-IPO  United States
# 2                     NaN    3/6/2023  Series B        Nigeria
# ...                   ...         ...       ...            ...
# 2358                 0.30   3/30/2020  Series A         Israel
# 2359                  NaN   9/14/2021  Post-IPO  United States
# ...

# %%
df[df['total_laid_off']<10].sort_values('total_laid_off')
# Out:
#                 company       location    industry  total_laid_off  \
# 1836             Branch  New York City      Retail             3.0
# 2348          Flytedesk        Boulder   Marketing             4.0
# 2126              Spyce         Boston        Food             4.0
# ...                 ...            ...         ...             ...
# 1431           BitOasis          Dubai      Crypto             9.0
# 2228  Incredible Health    SF Bay Area  Healthcare             9.0
# 2262          Iris Nova  New York City        Food             9.0
#
#       percentage_laid_off       date     stage               country  \
# 1836                 0.27  6/11/2020      Seed         United States
# 2348                 0.20  3/18/2020      Seed         United States
# 2126                 0.12   4/8/2020  Series A         United States
# ...                   ...        ...       ...                   ...
# 1431                 0.05  6/19/2022  Series B  United Arab Emirates
# ...

# %%
df[df['total_laid_off']<10].sort_values(by=['total_laid_off','industry'],ascending=False)
# total lais of is written forst so it organixe that first
# Out:
#                 company       location    industry  total_laid_off  \
# 677               &Open         Dublin   Marketing             9.0
# 2228  Incredible Health    SF Bay Area  Healthcare             9.0
# 2262          Iris Nova  New York City        Food             9.0
# ...                 ...            ...         ...             ...
# 2126              Spyce         Boston        Food             4.0
# 2000         TutorMundi      Sao Paulo   Education             4.0
# 1836             Branch  New York City      Retail             3.0
#
#       percentage_laid_off        date     stage        country  \
# 677                  0.09  11/17/2022  Series A        Ireland
# 2228                 0.40    4/1/2020  Series A  United States
# 2262                 0.50   3/30/2020      Seed  United States
# ...                   ...         ...       ...            ...
# 2126                 0.12    4/8/2020  Series A  United States
# ...

# %%
df['country'].sort_values()
# Out:
# 1571    Argentina
# 641     Argentina
# 352     Argentina
#           ...
# 1500      Vietnam
# 980       Vietnam
# 1910      Vietnam
# Name: country, Length: 2361, dtype: object

# %%
df[df['total_laid_off']<10].sort_values(by=['country','industry'],ascending=[True,False])
# Out:
#           company     location    industry  total_laid_off  \
# 1102    Expert360       Sydney  Recruiting             7.0
# 71          Kinde       Sydney       Other             8.0
# 2000   TutorMundi    Sao Paulo   Education             4.0
# ...           ...          ...         ...             ...
# 1806      Havenly       Denver    Consumer             5.0
# 1999       Jiobit      Chicago    Consumer             6.0
# 2353  Panda Squad  SF Bay Area    Consumer             6.0
#
#       percentage_laid_off       date     stage        country  \
# 1102                  NaN  8/11/2022  Series C      Australia
# 71                   0.28  2/20/2023      Seed      Australia
# 2000                 1.00  4/24/2020  Series A         Brazil
# ...                   ...        ...       ...            ...
# 1806                  NaN   7/1/2020  Series C  United States
# 1999                 0.21  4/24/2020   Unknown  United States
# ...

# %% [markdown]
# INDEXeing

# %%
df1 = pd.read_csv('/content/drive/MyDrive/world_population.csv',index_col='Country')
#each country is unique so great index
df1
# Out:
#              Rank CCA3  Capital Continent  2022 Population  2020 Population  \
# Country
# Afghanistan    36  AFG    Kabul      Asia       41128771.0       38972230.0
# Albania       138  ALB   Tirana    Europe        2842321.0        2866849.0
# Algeria        34  DZA  Algiers    Africa       44903225.0       43451666.0
# ...           ...  ...      ...       ...              ...              ...
# Yemen          46  YEM    Sanaa      Asia       33696614.0       32284046.0
# Zambia         63  ZMB   Lusaka    Africa       20017675.0       18927715.0
# Zimbabwe       74  ZWE   Harare    Africa       16320537.0       15669666.0
#
#              2015 Population  2010 Population  2000 Population  \
# Country
# Afghanistan       33753499.0       28189672.0       19542982.0
# Albania            2882481.0        2913399.0        3182021.0
# Algeria           39543154.0       35856344.0       30774621.0
# ...                      ...              ...              ...
# ...

# %%
df1.loc['Albania']
#df1.loc[1]
# Out:
# Rank                               138
# CCA3                               ALB
# Capital                         Tirana
#                                 ...
# Density (per km²)              98.8702
# Growth Rate                     0.9957
# World Population Percentage       0.04
# Name: Albania, Length: 16, dtype: object

# %%
df1 = df1.reset_index()
df1 = df1.set_index(['Continent','Country'])
df1.sort_index(level='Continent')
# Out:
#                          Rank CCA3     Capital  2022 Population  \
# Continent     Country
# Africa        Algeria      34  DZA     Algiers       44903225.0
#               Angola       42  AGO      Luanda       35588987.0
#               Benin        77  BEN  Porto-Novo       13352864.0
# ...                       ...  ...         ...              ...
# South America Suriname    170  SUR  Paramaribo         618040.0
#               Uruguay     133  URY  Montevideo        3422794.0
#               Venezuela    51  VEN     Caracas       28301696.0
#
#                          2020 Population  2015 Population  2010 Population  \
# Continent     Country
# Africa        Algeria         43451666.0       39543154.0       35856344.0
#               Angola          33428485.0       28127721.0       23364185.0
#               Benin           12643123.0       10932783.0        9445710.0
# ...                                  ...              ...              ...
# ...

# %%
df1.sort_index(level='Country',ascending=False)
# Out:
#                        Rank CCA3  Capital  2022 Population  2020 Population  \
# Continent Country
# Africa    Zimbabwe       74  ZWE   Harare       16320537.0       15669666.0
#           Zambia         63  ZMB   Lusaka       20017675.0       18927715.0
# Asia      Yemen          46  YEM    Sanaa       33696614.0       32284046.0
# ...                     ...  ...      ...              ...              ...
# Africa    Algeria        34  DZA  Algiers       44903225.0       43451666.0
# Europe    Albania       138  ALB   Tirana        2842321.0        2866849.0
# Asia      Afghanistan    36  AFG    Kabul       41128771.0       38972230.0
#
#                        2015 Population  2010 Population  2000 Population  \
# Continent Country
# Africa    Zimbabwe          14154937.0       12839771.0       11834676.0
#           Zambia                   NaN       13792086.0        9891136.0
# Asia      Yemen             28516545.0       24743946.0       18628700.0
# ...

# %%
df1.sort_index(ascending=[False,True])
# Out:
#                               Rank CCA3       Capital  2022 Population  \
# Continent     Country
# South America Argentina         33  ARG  Buenos Aires       45510318.0
#               Bolivia           80  BOL         Sucre       12224110.0
#               Brazil             7  BRA      Brasilia      215313498.0
# ...                            ...  ...           ...              ...
# Africa        Western Sahara   172  ESH      El Aaiún         575986.0
#               Zambia            63  ZMB        Lusaka       20017675.0
#               Zimbabwe          74  ZWE        Harare       16320537.0
#
#                               2020 Population  2015 Population  \
# Continent     Country
# South America Argentina            45036032.0       43257065.0
#               Bolivia              11936162.0       11090085.0
#               Brazil              213196304.0      205188205.0
# ...                                       ...              ...
# ...

# %%
df1.loc['Africa']
#search only first index which is continent
# Out:
#                 Rank CCA3     Capital  2022 Population  2020 Population  \
# Country
# Algeria           34  DZA     Algiers       44903225.0       43451666.0
# Angola            42  AGO      Luanda       35588987.0       33428485.0
# Benin             77  BEN  Porto-Novo       13352864.0       12643123.0
# ...              ...  ...         ...              ...              ...
# Western Sahara   172  ESH    El Aaiún         575986.0         556048.0
# Zambia            63  ZMB      Lusaka       20017675.0       18927715.0
# Zimbabwe          74  ZWE      Harare       16320537.0       15669666.0
#
#                 2015 Population  2010 Population  2000 Population  \
# Country
# Algeria              39543154.0       35856344.0       30774621.0
# Angola               28127721.0       23364185.0       16394062.0
# Benin                10932783.0        9445710.0        6998023.0
# ...                         ...              ...              ...
# ...

# %%
df1.loc['Africa','Capital']
# Out:
# Country
# Algeria              Algiers
# Angola                Luanda
# Benin             Porto-Novo
#                      ...
# Western Sahara      El Aaiún
# Zambia                Lusaka
# Zimbabwe              Harare
# Name: Capital, Length: 57, dtype: object

# %% [markdown]
# group by and aggregating
